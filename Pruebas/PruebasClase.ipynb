# %%
restaDosNumeros<-function(x,y){
    z<-x-y
    return(z)
}

# %%
restaDosNumeros(2,3)
# Out:
# [1] -1

# %%
ls()
# Out:
# [1] "restaDosNumeros"

# %%
alturas<-c(1.80,1.60,1.60,1.90,1.75,1.63,2.65)
puntos <-c(1,2,3,4,5,6,7)
alturas2<-c(1.70,1.65,1.45,1.95,1.95,1.60,1.83)

# %%
paste("Media:", mean(alturas))
paste("Varianza:", var(alturas))
paste("Desviacion Tipica:", sd(alturas))
# Out:
# [1] "Media: 1.69"
# [1] "Varianza: 0.0182"
# [1] "Desviacion Tipica: 0.13490737563232"

# %%
plot(puntos,alturas,xlab = "Puntos",ylab="Alturas", col="red")
points(puntos,alturas2,col="blue",pch="^")
grid()
# Out:
# plot without title

# %%
boxplot(alturas,alturas2)
grid()
# Out:
# plot without title

# %%
table <- table(alturas)
table
paste("Indice", which.max(table))
paste("Valor", max(table))
# Out:
# alturas
#  1.6 1.63 1.75  1.8  1.9 2.65
#    2    1    1    1    1    1
# [1] "Indice 1"
# [1] "Valor 2"

# %%
library("ggplot2")

# %%
valX<-seq(-2,0.1,by = 0.1)
valY <- (5*valX+5)*(50*valX+1)*(valX+2)
myDf <- data.frame(valX,valY)
myDf$type <- "funcion1"
valY2 <- (100*valX+5)*(2*valX+1)
myDf2 <- data.frame(valX,valY=valY2,type="funcion2")
myDf3 <- rbind(myDf,myDf2)
ggplot(data=myDf3,aes(x=valX,y=valY))+geom_line(aes(color=type))+geom_point(aes(color=type))+geom_vline(xintercept=0,color="blue")
# Out:
# plot without title

# %%
ggplot(data=myDf,aes(x=valX,y=valY))+geom_col(aes(color=type))
# Out:
# plot without title

# %%
dbinom(x=0,size=3,prob=0.5)
# Out:
# [1] 0.125

# %%
rbinom(10,size=1,prob=0.5)
# Out:
#  [1] 0 1 1 1 0 0 1 0 1 1

# %%
dpois(1,2)
# Out:
# [1] 0.2706706

# %%
dist <- rpois(500,2)
dist
mean(dist)
# Out:
#   [1] 1 4 1 2 3 1 4 3 1 5 4 4 4 0 5 2 4 3 1 1 0 3 1 2 3 1 1 4 3 3 2 1 4 0 1 1 3
#  [38] 1 2 2 0 3 3 1 2 2 2 2 2 3 2 4 3 1 1 3 4 2 1 1 3 1 4 1 3 4 1 1 3 1 4 1 4 2
#  [75] 0 3 1 1 1 3 1 3 0 4 3 2 0 2 1 1 2 6 2 0 2 3 2 2 2 0 3 3 2 0 4 3 3 2 4 2 5
# [112] 0 3 3 2 1 1 3 2 1 4 1 0 0 2 1 4 0 1 4 3 2 2 3 2 3 1 1 1 1 2 1 1 1 4 1 1 1
# [149] 1 2 0 2 1 2 4 0 2 1 1 5 6 1 2 2 2 1 5 4 3 3 3 3 2 0 2 3 3 3 2 2 0 4 2 2 2
# [186] 0 1 1 1 6 2 1 4 2 1 0 2 4 1 4 1 2 3 4 2 3 2 4 5 0 1 2 4 3 4 4 4 0 0 0 1 2
# [223] 1 2 0 1 3 3 1 1 4 3 2 1 0 2 2 2 1 3 3 5 2 2 2 1 4 0 1 3 4 3 1 3 1 3 1 0 2
# [260] 3 2 1 2 3 4 1 4 2 1 1 2 0 0 1 1 1 1 1 2 4 2 4 2 3 1 0 1 2 3 1 1 2 4 4 2 1
# [297] 1 4 3 1 0 1 2 5 4 3 3 3 2 0 5 3 2 2 2 0 2 0 1 2 4 2 0 0 0 2 2 1 2 0 1 2 0
# [334] 2 6 4 0 1 0 1 3 1 4 2 1 2 0 5 2 2 0 1 1 2 4 0 2 1 2 1 1 1 3 0 1 0 1 2 2 4
# [371] 1 2 1 0 0 0 0 4 2 0 2 1 0 3 2 1 3 0 4 5 0 1 1 2 1 2 1 1 1 1 3 3 2 1 3 3 1
# [408] 1 1 3 2 2 5 2 3 0 2 4 4 3 4 3 2 3 1 2 0 2 1 0 3 1 1 4 2 2 0 3 3 2 0 1 0 3
# [445] 1 3 1 0 4 1 3 3 1 0 1 2 0 3 0 0 1 1 3 4 3 3 0 2 3 0 4 4 2 2 4 1 5 2 3 3 2
# [482] 2 1 1 2 4 3 2 3 2 2 5 2 2 2 4 0 1 0 8
# [1] 2.002

# %%
exp <- rexp(100000,2)
mean(exp)
# Out:
# [1] 0.5019986

# %%
rnorm(20, mean=0,sd=1)
# Out:
#  [1]  2.42346877  0.55380172  0.69701063 -0.73531058  1.71017989  0.57930229
#  [7] -1.04613658  0.33188571  0.81979855  1.13129987  0.26668824 -0.86907393
# [13] -0.02542552 -0.97117871 -0.82326662 -0.47436747  0.82427752 -0.62714611
# [19]  0.21974935 -1.37951927

# %%
gausRandom <- sort(rnorm(1000, mean=0,sd=1))
qqnorm(gausRandom)
qqline(gausRandom, col="green", lwd=3)
# Out:
# Plot with title “Normal Q-Q Plot”

# %%
gausRandom <- sort(rbinom(1000,size=1,prob=0.5))
qqnorm(gausRandom)
qqline(gausRandom, col="green", lwd=3)
# Out:
# Plot with title “Normal Q-Q Plot”

# %%
v1 <- c(1,2,3,4,5,6,7,8,9)
v2 <- c(9,8,7,6,2,4,3,2,1)
cov(v1,v2)
cor(v1,v2)
# Out:
# [1] -7.5
# [1] -0.9393364

# %%
cbind(c(1,2,3),c(4,5,6))
# Out:
#      [,1] [,2]
# [1,] 1    4
# [2,] 2    5
# [3,] 3    6
